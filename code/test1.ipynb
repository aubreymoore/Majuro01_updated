# %%
 <image id="175" name="frame_000175" width="1080" height="1920">
    <box label="light" occluded="0" xtl="129.00" ytl="0.00" xbr="420.00" ybr="1415.00">
    </box>
    <box label="light" occluded="0" xtl="367.00" ytl="354.00" xbr="798.00" ybr="1862.00">
    </box>
    <box label="light" occluded="0" xtl="8.00" ytl="186.00" xbr="208.00" ybr="1223.00">
    </box>
    <box label="zero" occluded="0" xtl="743.00" ytl="1407.00" xbr="901.00" ybr="1890.00">
    </box>
  
  <image id="175" name="frame_000175" width="1080" height="1920">
    <polygon label="cut" occluded="0" points="25.00,280.50;12.00,280.50;4.50,274.00;2.50,251.00;14.50,224.00;27.00,207.50;52.00,208.50;65.50,219.00;65.50,240.00;50.50,264.00;25.00,280.50">
    </polygon>
    <polygon label="cut" occluded="0" points="451.00,57.50;426.00,49.50;419.50,43.00;415.50,20.00;421.00,4.50;451.00,3.50;462.00,12.50;474.00,6.50;481.50,7.00;484.50,35.00;464.00,41.50;456.50,55.00;451.00,57.50">
    </polygon>

# %%
import cv2
import glob

# %%
image_list = sorted(glob.glob('../rawdata/*.jpg'))

# %%
# frame_number = 9361
# fn = image_list[frame_number]
fn = '../rawdata/IMG_20231007_110805.jpg'
fn = '../rawdata/IMG_20231007_110806.jpg'
print(fn)
img = cv2.imread(fn)

colors = {'zero':(0,255,0), 'light':(0,0,255),'medium':(255,0,0),'high':(120,120,0),'non_recoverable':(0,120,120),'cut':(0,0,0)}

#draw boxes

# cv2.rectangle(img, (129,0), (420,1415), (255,0,0), 3)

# label="light"; occluded="0"; xtl=129; ytl=0; xbr=420; ybr=1415
# cv2.rectangle(img, (xtl, ytl), (xbr, ybr), colors[label], 5)

# label="light"; occluded="0"; xtl=367; ytl=354; xbr=798; ybr=1862
# cv2.rectangle(img, (xtl, ytl), (xbr, ybr), colors[label], 5)

# for label, bxes in boxes.items():
#     for box in bxes:
#             cv2.rectangle(frame, (box[0],box[1]), (box[2],box[3]), colors[label], 5)

cv2.rectangle(img, (1498, 614), (1845, 699), colors[label], 5)

cv2.imwrite('myimage.jpg', img)
# Out:
# ../rawdata/IMG_20231007_110806.jpg
# True

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
i = 0
for img in image_list[0:1000]:
    print(i, img)
    i = i + 1
# Out:
# 0 ../rawdata/IMG_20231007_110445.jpg
# 1 ../rawdata/IMG_20231007_110446.jpg
# 2 ../rawdata/IMG_20231007_110447.jpg
# 3 ../rawdata/IMG_20231007_110448.jpg
# 4 ../rawdata/IMG_20231007_110449.jpg
# 5 ../rawdata/IMG_20231007_110450.jpg
# 6 ../rawdata/IMG_20231007_110451.jpg
# 7 ../rawdata/IMG_20231007_110452.jpg
# 8 ../rawdata/IMG_20231007_110453.jpg
# 9 ../rawdata/IMG_20231007_110454.jpg
# 10 ../rawdata/IMG_20231007_110455.jpg
# 11 ../rawdata/IMG_20231007_110456.jpg
# 12 ../rawdata/IMG_20231007_110457.jpg
# 13 ../rawdata/IMG_20231007_110459.jpg
# 14 ../rawdata/IMG_20231007_110500.jpg
# 15 ../rawdata/IMG_20231007_110501.jpg
# 16 ../rawdata/IMG_20231007_110502.jpg
# 17 ../rawdata/IMG_20231007_110503.jpg
# 18 ../rawdata/IMG_20231007_110601.jpg
# 19 ../rawdata/IMG_20231007_110602.jpg
# 20 ../rawdata/IMG_20231007_110603.jpg
# 21 ../rawdata/IMG_20231007_110604.jpg
# 22 ../rawdata/IMG_20231007_110605.jpg
# 23 ../rawdata/IMG_20231007_110606.jpg
# 24 ../rawdata/IMG_20231007_110608.jpg
# ...

# %%
image_list[133]
# Out:
# '../rawdata/IMG_20231007_110804.jpg'
